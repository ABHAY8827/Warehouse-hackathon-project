# %% [markdown]
# ## Demand forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"E:\Data science\Warehouse dataset hackerearth\train.csv")

# %%
data.head()
# Out:
#        ID        date warehouse_ID   Latitude   Longitude Product_Type  year  \
# 0  0x2710  2017-01-01     WH_0x3e9  41.681471  -72.794746       Type_A  2017
# 1  0x33e6  2017-01-01     WH_0x3ea  38.749077 -105.183060       Type_A  2017
# 2  0x2711  2017-01-02     WH_0x3e9  41.681471  -72.794746       Type_A  2017
# 3  0x33e7  2017-01-02     WH_0x3ea  38.749077 -105.183060       Type_A  2017
# 4  0x2712  2017-01-03     WH_0x3e9  41.681471  -72.794746       Type_A  2017
#
#      month is_weekend is_warehouse_closed  daily_dispatch_count  \
# 0  January        Yes                  No                   5.5
# 1  January        Yes                  No                   6.1
# 2  January         No                  No                   4.8
# 3  January         No                  No                   6.7
# 4  January         No                  No                   5.8
#
#    weekly_dispatch_count
# 0                    5.5
# 1                    6.1
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
data.isnull().sum()
# Out:
# ID                           0
# date                         0
# warehouse_ID                 0
# Latitude                   332
# Longitude                  416
# Product_Type                 0
# year                         0
# month                        0
# is_weekend                 499
# is_warehouse_closed        166
# daily_dispatch_count         0
# weekly_dispatch_count    14272
# dtype: int64

# %%
data.shape
# Out:
# (16644, 12)

# %% [markdown]
# ## feature engineering

# %% [markdown]
# #### - latitude and longitude - first remove null values and then create state and city by it
# #### -  product_type - Labelencoder
# #### -  month - label_encoder
# #### -  isWeekend - simple_imputer(mode) and label_encoder
# #### - is_warehouse_closed - mode and label_encoder
# #### - weekly_dispatch_count - iterative imputer([daily_dispatch_count])

# %%
for i,j in data['Longitude'].items():
    if(np.isnan(j)):
        print("index is",i)
# Out:
# index is 49
# index is 52
# index is 79
# index is 116
# index is 213
# index is 280
# index is 305
# index is 331
# index is 381
# index is 504
# index is 516
# index is 519
# index is 558
# index is 603
# index is 613
# index is 624
# index is 644
# index is 672
# index is 727
# index is 736
# index is 782
# index is 820
# index is 837
# index is 899
# index is 919
# index is 966
# index is 1076
# index is 1094
# index is 1152
# index is 1203
# index is 1332
# index is 1361
# index is 1455
# index is 1500
# index is 1548
# index is 1595
# index is 1639
# index is 1653
# index is 1666
# index is 1675
# index is 1699
# index is 1729
# index is 1771
# index is 1783
# index is 1839
# index is 1882
# index is 1911
# index is 1917
# index is 1954
# index is 1993
# index is 2067
# index is 2128
# index is 2162
# index is 2227
# index is 2245
# index is 2258
# index is 2334
# index is 2392
# index is 2408
# index is 2458
# index is 2475
# index is 2479
# index is 2493
# index is 2521
# index is 2567
# index is 2591
# index is 2610
# index is 2613
# index is 2660
# index is 2666
# index is 2673
# index is 2678
# index is 2693
# index is 2813
# index is 2831
# index is 2865
# index is 2867
# index is 2953
# index is 3094
# index is 3101
# index is 3126
# index is 3165
# index is 3172
# index is 3178
# index is 3203
# index is 3213
# index is 3270
# index is 3284
# index is 3496
# index is 3524
# index is 3528
# index is 3643
# index is 3661
# index is 3663
# index is 3751
# index is 3805
# index is 3823
# index is 3827
# index is 3836
# index is 3923
# index is 3978
# index is 4035
# index is 4093
# index is 4119
# index is 4205
# index is 4223
# index is 4335
# index is 4368
# index is 4411
# index is 4414
# index is 4434
# index is 4463
# index is 4472
# index is 4514
# index is 4557
# index is 4576
# index is 4594
# index is 4625
# index is 4659
# index is 4675
# index is 4682
# index is 4698
# index is 4725
# index is 4733
# index is 4747
# index is 4789
# index is 4800
# index is 4881
# index is 4898
# index is 4904
# index is 4909
# index is 4923
# index is 4951
# index is 4964
# index is 5017
# index is 5057
# index is 5158
# index is 5179
# index is 5186
# index is 5207
# index is 5220
# index is 5274
# index is 5312
# index is 5320
# index is 5352
# index is 5364
# index is 5378
# index is 5409
# index is 5463
# index is 5483
# index is 5522
# index is 5617
# index is 5652
# index is 5663
# index is 5729
# index is 5783
# index is 5832
# index is 5850
# index is 5855
# index is 5877
# index is 5896
# index is 6016
# index is 6028
# index is 6049
# index is 6083
# index is 6125
# index is 6129
# index is 6294
# index is 6304
# index is 6325
# index is 6354
# index is 6362
# index is 6400
# index is 6463
# index is 6501
# index is 6675
# index is 6697
# index is 6745
# index is 6812
# index is 6821
# index is 6874
# index is 6923
# index is 7007
# index is 7023
# index is 7042
# index is 7057
# index is 7069
# index is 7192
# index is 7194
# index is 7260
# index is 7275
# index is 7278
# index is 7400
# index is 7434
# index is 7460
# index is 7511
# index is 7695
# index is 7712
# index is 7730
# index is 7756
# index is 7763
# index is 7765
# index is 7767
# index is 7881
# index is 7984
# index is 8103
# index is 8143
# index is 8154
# index is 8194
# index is 8225
# index is 8247
# index is 8340
# index is 8371
# index is 8429
# index is 8455
# index is 8485
# index is 8501
# index is 8510
# index is 8532
# index is 8547
# index is 8618
# index is 8679
# index is 8728
# index is 8765
# index is 8793
# index is 8840
# index is 8844
# index is 8848
# index is 8882
# index is 8902
# index is 8927
# index is 8958
# index is 9006
# index is 9040
# index is 9046
# index is 9049
# index is 9059
# index is 9097
# index is 9116
# index is 9152
# index is 9213
# index is 9268
# index is 9294
# index is 9297
# index is 9356
# index is 9361
# index is 9414
# index is 9477
# index is 9591
# index is 9610
# index is 9716
# index is 9791
# index is 9805
# index is 9863
# index is 9907
# index is 9921
# index is 9991
# index is 10099
# index is 10182
# index is 10233
# index is 10263
# index is 10319
# index is 10320
# index is 10326
# index is 10386
# index is 10390
# index is 10447
# index is 10561
# index is 10564
# index is 10643
# index is 10851
# index is 10852
# index is 10873
# index is 10904
# index is 10935
# index is 10967
# index is 10970
# index is 11013
# index is 11039
# index is 11070
# index is 11084
# index is 11106
# index is 11136
# index is 11174
# index is 11178
# index is 11181
# index is 11279
# index is 11357
# index is 11368
# index is 11448
# index is 11450
# index is 11478
# index is 11561
# index is 11730
# index is 11761
# index is 11898
# index is 11910
# index is 11918
# index is 12001
# index is 12024
# index is 12045
# index is 12101
# index is 12172
# index is 12270
# index is 12293
# index is 12353
# index is 12375
# index is 12407
# index is 12418
# index is 12426
# index is 12521
# index is 12546
# index is 12612
# index is 12649
# index is 12663
# index is 12687
# index is 12692
# index is 12803
# index is 12842
# index is 12846
# index is 12980
# index is 12992
# index is 13002
# index is 13011
# index is 13054
# index is 13055
# index is 13071
# index is 13119
# index is 13162
# index is 13292
# index is 13306
# index is 13319
# index is 13335
# index is 13362
# index is 13511
# index is 13530
# index is 13535
# index is 13539
# index is 13615
# index is 13669
# index is 13681
# index is 13789
# index is 13887
# index is 13924
# index is 13952
# index is 13955
# index is 13969
# index is 14017
# index is 14038
# index is 14052
# index is 14104
# index is 14189
# index is 14227
# index is 14258
# index is 14302
# index is 14385
# index is 14455
# index is 14459
# index is 14619
# index is 14634
# index is 14650
# index is 14654
# index is 14677
# index is 14700
# index is 14749
# index is 14765
# index is 14789
# index is 14799
# index is 14933
# index is 14939
# index is 14956
# index is 15006
# index is 15131
# index is 15134
# index is 15181
# index is 15194
# index is 15246
# index is 15252
# index is 15269
# index is 15276
# index is 15296
# index is 15301
# index is 15303
# index is 15314
# index is 15319
# index is 15333
# index is 15351
# index is 15363
# index is 15439
# index is 15482
# index is 15581
# index is 15636
# index is 15651
# index is 15787
# index is 15816
# index is 15990
# index is 16034
# index is 16037
# index is 16047
# index is 16052
# index is 16059
# index is 16152
# index is 16202
# index is 16235
# index is 16270
# index is 16273
# index is 16325
# index is 16330
# index is 16347
# index is 16396
# index is 16435
# index is 16464
# index is 16527
# index is 16531
# index is 16574
# index is 16611

# %%
for i,j in data['Latitude'].items():
    if(np.isnan(j)):
        print("index is",i)
# Out:
# index is 13
# index is 46
# index is 79
# index is 80
# index is 87
# index is 98
# index is 130
# index is 147
# index is 223
# index is 234
# index is 303
# index is 317
# index is 401
# index is 440
# index is 443
# index is 464
# index is 550
# index is 585
# index is 707
# index is 715
# index is 745
# index is 753
# index is 841
# index is 854
# index is 910
# index is 947
# index is 948
# index is 972
# index is 1023
# index is 1038
# index is 1163
# index is 1197
# index is 1249
# index is 1305
# index is 1424
# index is 1498
# index is 1538
# index is 1547
# index is 1571
# index is 1573
# index is 1613
# index is 1623
# index is 1662
# index is 1747
# index is 1770
# index is 1805
# index is 1811
# index is 1822
# index is 1861
# index is 1893
# index is 1954
# index is 2048
# index is 2087
# index is 2162
# index is 2219
# index is 2220
# index is 2251
# index is 2280
# index is 2318
# index is 2376
# index is 2408
# index is 2534
# index is 2551
# index is 2556
# index is 2621
# index is 2639
# index is 2774
# index is 2808
# index is 2858
# index is 2916
# index is 2925
# index is 2978
# index is 3043
# index is 3100
# index is 3121
# index is 3147
# index is 3152
# index is 3200
# index is 3246
# index is 3301
# index is 3343
# index is 3439
# index is 3445
# index is 3527
# index is 3774
# index is 3868
# index is 4044
# index is 4126
# index is 4229
# index is 4251
# index is 4270
# index is 4332
# index is 4499
# index is 4569
# index is 4574
# index is 4645
# index is 4747
# index is 4861
# index is 4888
# index is 4943
# index is 4984
# index is 5004
# index is 5008
# index is 5079
# index is 5082
# index is 5098
# index is 5107
# index is 5119
# index is 5257
# index is 5445
# index is 5542
# index is 5598
# index is 5622
# index is 5629
# index is 5728
# index is 5745
# index is 5786
# index is 5820
# index is 5914
# index is 6085
# index is 6146
# index is 6161
# index is 6174
# index is 6258
# index is 6268
# index is 6352
# index is 6364
# index is 6375
# index is 6453
# index is 6483
# index is 6702
# index is 6964
# index is 7018
# index is 7131
# index is 7223
# index is 7277
# index is 7317
# index is 7368
# index is 7414
# index is 7445
# index is 7451
# index is 7460
# index is 7501
# index is 7511
# index is 7641
# index is 7725
# index is 7775
# index is 7813
# index is 7978
# index is 8101
# index is 8128
# index is 8219
# index is 8429
# index is 8529
# index is 8557
# index is 8569
# index is 8572
# index is 8599
# index is 8718
# index is 8749
# index is 8754
# index is 8848
# index is 8871
# index is 8934
# index is 8978
# index is 9035
# index is 9108
# index is 9152
# index is 9201
# index is 9248
# index is 9255
# index is 9378
# index is 9411
# index is 9441
# index is 9452
# index is 9501
# index is 9509
# index is 9555
# index is 9557
# index is 9561
# index is 9565
# index is 9595
# index is 9641
# index is 9728
# index is 9781
# index is 9788
# index is 9803
# index is 9805
# index is 9823
# index is 9932
# index is 9941
# index is 10006
# index is 10034
# index is 10071
# index is 10087
# index is 10163
# index is 10165
# index is 10171
# index is 10181
# index is 10229
# index is 10248
# index is 10339
# index is 10375
# index is 10397
# index is 10514
# index is 10569
# index is 10601
# index is 10615
# index is 10632
# index is 10634
# index is 10675
# index is 10830
# index is 10894
# index is 10949
# index is 11018
# index is 11056
# index is 11059
# index is 11074
# index is 11111
# index is 11227
# index is 11295
# index is 11323
# index is 11367
# index is 11380
# index is 11415
# index is 11497
# index is 11593
# index is 11633
# index is 11727
# index is 11755
# index is 11799
# index is 11808
# index is 11939
# index is 11943
# index is 11984
# index is 12022
# index is 12040
# index is 12101
# index is 12122
# index is 12134
# index is 12249
# index is 12305
# index is 12369
# index is 12373
# index is 12390
# index is 12482
# index is 12551
# index is 12561
# index is 12582
# index is 12635
# index is 12645
# index is 12704
# index is 12838
# index is 12856
# index is 12895
# index is 12914
# index is 12967
# index is 13022
# index is 13037
# index is 13272
# index is 13283
# index is 13397
# index is 13411
# index is 13493
# index is 13497
# index is 13504
# index is 13532
# index is 13581
# index is 13587
# index is 13622
# index is 13748
# index is 13756
# index is 13824
# index is 13856
# index is 13909
# index is 14005
# index is 14065
# index is 14130
# index is 14142
# index is 14178
# index is 14187
# index is 14220
# index is 14260
# index is 14270
# index is 14279
# index is 14318
# index is 14330
# index is 14388
# index is 14408
# index is 14430
# index is 14439
# index is 14448
# index is 14454
# index is 14458
# index is 14475
# index is 14493
# index is 14523
# index is 14546
# index is 14556
# index is 14626
# index is 14807
# index is 15012
# index is 15064
# index is 15071
# index is 15167
# index is 15212
# index is 15260
# index is 15327
# index is 15373
# index is 15374
# index is 15385
# index is 15389
# index is 15469
# index is 15479
# index is 15489
# index is 15516
# index is 15572
# index is 15580
# index is 15602
# index is 15626
# index is 15635
# index is 15686
# index is 15718
# index is 15833
# index is 15907
# index is 15920
# index is 15934
# index is 16227
# index is 16279
# index is 16354
# index is 16400
# index is 16490

# %%
data.isnull().sum()
# Out:
# ID                           0
# date                         0
# warehouse_ID                 0
# Latitude                   332
# Longitude                  416
# Product_Type                 0
# year                         0
# month                        0
# is_weekend                 499
# is_warehouse_closed        166
# daily_dispatch_count         0
# weekly_dispatch_count    14272
# dtype: int64

# %%
from sklearn.experimental import enable_iterative_imputer
# import Iterative imputer
from sklearn.impute import IterativeImputer

# %%
iter_impute=IterativeImputer()
iter_imp=pd.DataFrame(iter_impute.fit_transform(data[['daily_dispatch_count','weekly_dispatch_count']]),columns=['daily_dispatch_count','weekly_dispatch_count'])
iter_imp
# Out:
#        daily_dispatch_count  weekly_dispatch_count
# 0                       5.5               5.500000
# 1                       6.1               6.100000
# 2                       4.8              36.012933
# 3                       6.7              47.869663
# 4                       5.8              42.253317
# ...                     ...                    ...
# 16639                   0.2               7.307168
# 16640                  12.3              82.815812
# 16641                   3.3              26.652357
# 16642                   7.1              50.365816
# 16643                   3.4              27.276396
#
# [16644 rows x 2 columns]

# %%
iter_imp
# Out:
#        daily_dispatch_count  weekly_dispatch_count
# 0                       5.5               5.500000
# 1                       6.1               6.100000
# 2                       4.8              36.012933
# 3                       6.7              47.869663
# 4                       5.8              42.253317
# ...                     ...                    ...
# 16639                   0.2               7.307168
# 16640                  12.3              82.815812
# 16641                   3.3              26.652357
# 16642                   7.1              50.365816
# 16643                   3.4              27.276396
#
# [16644 rows x 2 columns]

# %%
data[['daily_dispatch_count','weekly_dispatch_count']] = iter_imp

# %%
data.isnull().sum()
# Out:
# ID                         0
# date                       0
# warehouse_ID               0
# Latitude                 332
# Longitude                416
# Product_Type               0
# year                       0
# month                      0
# is_weekend               499
# is_warehouse_closed      166
# daily_dispatch_count       0
# weekly_dispatch_count      0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                       0
# date                     0
# warehouse_ID             0
# Latitude                 0
# Longitude                0
# Product_Type             0
# year                     0
# month                    0
# is_weekend               0
# is_warehouse_closed      0
# daily_dispatch_count     0
# weekly_dispatch_count    0
# dtype: int64

# %%
data.shape
# Out:
# (15272, 12)

# %%
# Data loss
(15272 - 16644)/15272
# Out:
# -0.08983761131482451

# %%
data['Longitude']
# Out:
# 0        -72.794746
# 1       -105.183060
# 2        -72.794746
# 3       -105.183060
# 4        -72.794746
#             ...
# 16639    -89.829262
# 16640   -116.319862
# 16641   -116.319862
# 16642   -149.125259
# 16643   -149.125259
# Name: Longitude, Length: 15272, dtype: float64

# %%
lis = []
for x in data['Longitude']:
    first =float(x) + 359
    lis.append(first)
data['Longitude'] = lis

# %%
data
# Out:
#            ID        date warehouse_ID   Latitude   Longitude Product_Type  \
# 0      0x2710  2017-01-01     WH_0x3e9  41.681471  286.205254       Type_A
# 1      0x33e6  2017-01-01     WH_0x3ea  38.749077  253.816940       Type_A
# 2      0x2711  2017-01-02     WH_0x3e9  41.681471  286.205254       Type_A
# 3      0x33e7  2017-01-02     WH_0x3ea  38.749077  253.816940       Type_A
# 4      0x2712  2017-01-03     WH_0x3e9  41.681471  286.205254       Type_A
# ...       ...         ...          ...        ...         ...          ...
# 16639  0x6f53  2021-04-30     WH_0x3f0  37.915825  269.170738       Type_B
# 16640  0x74c8  2021-04-30     WH_0x3f1  48.692551  242.680138       Type_A
# 16641  0x74c9  2021-04-30     WH_0x3f1  48.692551  242.680138       Type_B
# 16642  0x794c  2021-04-30     WH_0x3f2  61.600803  209.874741       Type_A
# 16643  0x794d  2021-04-30     WH_0x3f2  61.600803  209.874741       Type_B
#
#        year    month is_weekend is_warehouse_closed  daily_dispatch_count  \
# 0      2017  January        Yes                  No                   5.5
# 1      2017  January        Yes                  No                   6.1
# 2      2017  January         No                  No                   4.8
# 3      2017  January         No                  No                   6.7
# 4      2017  January         No                  No                   5.8
# ...     ...      ...        ...                 ...                   ...
# 16639  2021    April         No                  No                   0.2
# 16640  2021    April         No                  No                  12.3
# 16641  2021    April         No                  No                   3.3
# 16642  2021    April         No                  No                   7.1
# 16643  2021    April         No                  No                   3.4
#
#        weekly_dispatch_count
# 0                   5.500000
# 1                   6.100000
# 2                  36.012933
# 3                  47.869663
# 4                  42.253317
# ...                      ...
# 16639               7.307168
# 16640              82.815812
# 16641              26.652357
# 16642              50.365816
# 16643              27.276396
#
# [15272 rows x 12 columns]

# %%
### Lattitude and longitude - city and state

# %%
import reverse_geocoder as rg
import pprint
data00=[]
def reverseGeocode(coordinates):
    result=rg.search(coordinates)
    return(result)
if __name__=="__main__":
    coordinates=list(zip(data['Latitude'],data['Longitude']))
    data12=reverseGeocode(coordinates)
    data00.append(data12)

new_data=pd.DataFrame(data00).transpose()
# Out:
# Loading formatted geocoded file...

# %%
data12
# Out:
# [{'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
# ...
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  {'lat': '63.06101',
#   'lon': '179.35046',
#   'name': 'Beringovskiy',
#   'admin1': 'Chukotskiy Avtonomnyy Okrug',
#   'admin2': '',
#   'cc': 'RU'},
#  ...]

# %%
data['state']=new_data[0].apply(lambda x:x.get('admin1'))
data['Country']=new_data[0].apply(lambda x:x.get('cc'))

# %%
data.head()
# Out:
#        ID        date warehouse_ID   Latitude   Longitude Product_Type  year  \
# 0  0x2710  2017-01-01     WH_0x3e9  41.681471  286.205254       Type_A  2017
# 1  0x33e6  2017-01-01     WH_0x3ea  38.749077  253.816940       Type_A  2017
# 2  0x2711  2017-01-02     WH_0x3e9  41.681471  286.205254       Type_A  2017
# 3  0x33e7  2017-01-02     WH_0x3ea  38.749077  253.816940       Type_A  2017
# 4  0x2712  2017-01-03     WH_0x3e9  41.681471  286.205254       Type_A  2017
#
#      month is_weekend is_warehouse_closed  daily_dispatch_count  \
# 0  January        Yes                  No                   5.5
# 1  January        Yes                  No                   6.1
# 2  January         No                  No                   4.8
# 3  January         No                  No                   6.7
# 4  January         No                  No                   5.8
#
#    weekly_dispatch_count                        state Country
# 0               5.500000  Chukotskiy Avtonomnyy Okrug      RU
# 1               6.100000  Chukotskiy Avtonomnyy Okrug      RU
# 2              36.012933  Chukotskiy Avtonomnyy Okrug      RU
# 3              47.869663  Chukotskiy Avtonomnyy Okrug      RU
# 4              42.253317  Chukotskiy Avtonomnyy Okrug      RU

# %%
data['Product_Type'].unique()
# Out:
# array(['Type_A', 'Type_B'], dtype=object)

# %%
data.drop(columns=['ID','warehouse_ID','Latitude','Longitude'],inplace=True)

# %%
data.head()
# Out:
#          date Product_Type  year    month is_weekend is_warehouse_closed  \
# 0  2017-01-01       Type_A  2017  January        Yes                  No
# 1  2017-01-01       Type_A  2017  January        Yes                  No
# 2  2017-01-02       Type_A  2017  January         No                  No
# 3  2017-01-02       Type_A  2017  January         No                  No
# 4  2017-01-03       Type_A  2017  January         No                  No
#
#    daily_dispatch_count  weekly_dispatch_count                        state  \
# 0                   5.5               5.500000  Chukotskiy Avtonomnyy Okrug
# 1                   6.1               6.100000  Chukotskiy Avtonomnyy Okrug
# 2                   4.8              36.012933  Chukotskiy Avtonomnyy Okrug
# 3                   6.7              47.869663  Chukotskiy Avtonomnyy Okrug
# 4                   5.8              42.253317  Chukotskiy Avtonomnyy Okrug
#
#   Country
# 0      RU
# 1      RU
# 2      RU
# 3      RU
# 4      RU

# %%
from datetime import datetime

# %%
data['date'] = pd.to_datetime(data['date'], errors='coerce')
data['weak-of-year'] = data['date'].dt.weekofyear
data['Quarter'] = data.date.dt.quarter
data['day-of-week'] = data['date'].dt.dayofweek

# %%
data['days_in_month'] = data.date.dt.days_in_month

# %%
data.head()
# Out:
#         date Product_Type  year    month is_weekend is_warehouse_closed  \
# 0 2017-01-01       Type_A  2017  January        Yes                  No
# 1 2017-01-01       Type_A  2017  January        Yes                  No
# 2 2017-01-02       Type_A  2017  January         No                  No
# 3 2017-01-02       Type_A  2017  January         No                  No
# 4 2017-01-03       Type_A  2017  January         No                  No
#
#    daily_dispatch_count  weekly_dispatch_count                        state  \
# 0                   5.5               5.500000  Chukotskiy Avtonomnyy Okrug
# 1                   6.1               6.100000  Chukotskiy Avtonomnyy Okrug
# 2                   4.8              36.012933  Chukotskiy Avtonomnyy Okrug
# 3                   6.7              47.869663  Chukotskiy Avtonomnyy Okrug
# 4                   5.8              42.253317  Chukotskiy Avtonomnyy Okrug
#
#   Country  weak-of-year  Quarter  day-of-week  days_in_month
# 0      RU            52        1            6             31
# 1      RU            52        1            6             31
# 2      RU             1        1            0             31
# 3      RU             1        1            0             31
# 4      RU             1        1            1             31

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
data['Product_Type'] = lab_enc.fit_transform(data['Product_Type'])
data['month'] = lab_enc.fit_transform(data['month'])
data['is_weekend'] = lab_enc.fit_transform(data['is_weekend'])
data['is_warehouse_closed'] = lab_enc.fit_transform(data['is_warehouse_closed'])
data['state'] = lab_enc.fit_transform(data['state'])
data['Country'] = lab_enc.fit_transform(data['Country'])

# %%
data.head()
# Out:
#         date  Product_Type  year  month  is_weekend  is_warehouse_closed  \
# 0 2017-01-01             0  2017      4           1                    0
# 1 2017-01-01             0  2017      4           1                    0
# 2 2017-01-02             0  2017      4           0                    0
# 3 2017-01-02             0  2017      4           0                    0
# 4 2017-01-03             0  2017      4           0                    0
#
#    daily_dispatch_count  weekly_dispatch_count  state  Country  weak-of-year  \
# 0                   5.5               5.500000      0        0            52
# 1                   6.1               6.100000      0        0            52
# 2                   4.8              36.012933      0        0             1
# 3                   6.7              47.869663      0        0             1
# 4                   5.8              42.253317      0        0             1
#
#    Quarter  day-of-week  days_in_month
# 0        1            6             31
# 1        1            6             31
# 2        1            0             31
# 3        1            0             31
# 4        1            1             31

# %%
data.drop(columns=['date'],inplace=True)

# %%
## making features and label
X = data.drop(columns=['weekly_dispatch_count','daily_dispatch_count'])
y = data['weekly_dispatch_count']

# %% [markdown]
# ### Model building

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_percentage_error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train) 
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1) == round(r2_score(y_test,pred_test)*100,1):
        print("At random state",i,"model perform very well")
        print("At random state",i,",")
        mape = mean_absolute_percentage_error(y_test,pred_test)
        score = max(0, 100*(1-mape))
        print('Score :', score)
        mse = mean_squared_error(y_test,pred_test)
        print('RMSE :', np.sqrt(mse))
# Out:
# At random state 17 model perform very well
# At random state 17 ,
# Score : 59.53530679856609
# RMSE : 12.112340905024224
# At random state 18 model perform very well
# At random state 18 ,
# Score : 59.44010951856515
# RMSE : 12.191749539314939
# At random state 50 model perform very well
# At random state 50 ,
# Score : 59.032342488949176
# RMSE : 12.468202354910689
# At random state 64 model perform very well
# At random state 64 ,
# Score : 0
# RMSE : 12.428689100388645
# At random state 72 model perform very well
# At random state 72 ,
# Score : 0
# RMSE : 11.988681264850085
# At random state 123 model perform very well
# At random state 123 ,
# Score : 60.09326990419035
# RMSE : 12.65538838569721
# At random state 134 model perform very well
# At random state 134 ,
# Score : 58.76556564621889
# RMSE : 12.432826544237503
# At random state 191 model perform very well
# At random state 191 ,
# Score : 61.79191050244792
# RMSE : 12.262919251122176
# At random state 194 model perform very well
# At random state 194 ,
# Score : 59.40495776094464
# RMSE : 12.465694685845804
# At random state 200 model perform very well
# At random state 200 ,
# Score : 62.84029448785291
# RMSE : 12.21667223275639
# At random state 243 model perform very well
# At random state 243 ,
# Score : 59.37086950606159
# RMSE : 12.425937611621091
# At random state 362 model perform very well
# At random state 362 ,
# Score : 61.73241945851795
# RMSE : 12.166213589682352
# At random state 389 model perform very well
# At random state 389 ,
# Score : 61.19039877569842
# RMSE : 12.37583378651372
# At random state 418 model perform very well
# At random state 418 ,
# Score : 58.875136649356776
# RMSE : 11.994236415958069
# At random state 452 model perform very well
# At random state 452 ,
# Score : 59.703326680181014
# RMSE : 11.94192499802291
# At random state 455 model perform very well
# At random state 455 ,
# Score : 57.067672590539686
# RMSE : 12.024001329160052
# At random state 486 model perform very well
# At random state 486 ,
# Score : 57.39216460084451
# RMSE : 12.357358596495173
# At random state 570 model perform very well
# At random state 570 ,
# Score : 58.62717946000681
# RMSE : 12.125304908857421
# At random state 609 model perform very well
# At random state 609 ,
# Score : 59.92920878045387
# RMSE : 12.198157662467779
# At random state 636 model perform very well
# At random state 636 ,
# Score : 61.24240177783476
# RMSE : 12.530949488146012
# At random state 654 model perform very well
# At random state 654 ,
# Score : 61.26327080393471
# RMSE : 12.015633258835052
# At random state 667 model perform very well
# At random state 667 ,
# Score : 60.40588089183594
# RMSE : 12.04473541710721
# At random state 674 model perform very well
# At random state 674 ,
# Score : 60.31139336715157
# RMSE : 12.3507938742323
# At random state 775 model perform very well
# At random state 775 ,
# Score : 60.74494686983354
# RMSE : 12.312123818783938
# At random state 833 model perform very well
# At random state 833 ,
# Score : 59.86218189585835
# RMSE : 12.687059604422076
# At random state 865 model perform very well
# At random state 865 ,
# Score : 59.465930609345484
# RMSE : 12.129931280589059
# At random state 926 model perform very well
# At random state 926 ,
# Score : 61.26693094440376
# RMSE : 12.063569825137463
# At random state 975 model perform very well
# At random state 975 ,
# Score : 59.259313745730545
# RMSE : 12.265543726536478
# At random state 995 model perform very well
# At random state 995 ,
# Score : 59.37772955543381
# RMSE : 12.016690127594645

# %% [markdown]
# ## Random_state = 478

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state=478)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
print("mean_absolute_error",mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 58.941541835408295
# mean_absolute_error 9.225275808895038
# RMSE : 12.420949416888076

# %% [markdown]
# ## Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 72.6124430464991
# RMSE : 11.180534624052774

# %% [markdown]
# ## Gradient Boosting regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)
pred = gb.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-(mape)))
print('Score :', score)
print(mean_absolute_error(y_test,pred))
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 72.0500633148947
# 7.175198636340785
# RMSE : 10.018678942217695

# %% [markdown]
# ## XGBT

# %%
from xgboost import XGBRegressor
xgbt = XGBRegressor()
xgbt.fit(x_train,y_train)
pred = xgbt.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 73.27572838240273
# RMSE : 10.25390747719579

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(lr, X, y, cv=5)
print("Cross validation score of linear regression model is",scr.mean()*100)
# Out:
# Cross validation score of linear regression model is 35.432193985816205

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(rf, X, y, cv=5)
print("Cross validation score of Random forest regression model is",scr.mean()*100)
# Out:
# Cross validation score of Random forest regression model is 52.94394667760385

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(gb, X, y, cv=5)
print("Cross validation score of gradient boosting regression model is",scr.mean()*100)
# Out:
# Cross validation score of gradient boosting regression model is 57.699752172784436

# %%
from sklearn.model_selection import cross_val_score
scr = cross_val_score(xgbt, X, y, cv=5)
print("Cross validation score of xtreme gradient boosting regression model is",scr.mean()*100)
# Out:
# Cross validation score of xtreme gradient boosting regression model is 56.192738628989446

# %% [markdown]
# ### Hyperparameter tuning Random forest regressor model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rlf=RandomForestRegressor()
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=.10,random_state=478)
params = {'n_estimators':[120,140],
        'min_samples_split':[1,8],
        'min_samples_leaf':[1,5],
        'max_features': range(3,6)
        }
grd = GridSearchCV(rlf,param_grid = params)
grd.fit(x_train,y_train)
print('best_pram', grd.best_params_)

rf=grd.best_estimator_ #reinstantiating with best params

rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

mape = mean_absolute_percentage_error(y_test,y_pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,y_pred)
print('RMSE :', np.sqrt(mse))

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 72.63348475240076
# RMSE : 11.168999963843607

# %% [markdown]
# ### Hypertuning - Gradient Boosting model

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in Gridsearchcv
parameter ={'learning_rate': np.arange(0.1,0.3,0.1),
           'max_depth':range(2,8,2),
            'min_samples_split':range(2,4),
            'min_samples_leaf':range(1,7),
            'max_features':range(3,8),
            'n_estimators': range(100,140,5)
           }
grd = GridSearchCV(gb,param_grid = params)
grd.fit(x_train,y_train)
print('best_pram', grd.best_params_)

gb=grd.best_estimator_ #reinstantiating with best params

gb.fit(x_train,y_train)
pred = gb.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train,y_train)

pred = gb.predict(x_test)
mape = mean_absolute_percentage_error(y_test,pred)
score = max(0, 100*(1-mape))
print('Score :', score)
mse = mean_squared_error(y_test,pred)
print('RMSE :', np.sqrt(mse))
# Out:
# Score : 72.05006331489471
# RMSE : 10.018678942217695

# %% [markdown]
# ### Test data

# %%
test_data = pd.read_csv('test.csv')
test_data.head()
# Out:
#        ID        date warehouse_ID   Latitude   Longitude Product_Type  year  \
# 0  0x31fc  2021-05-01     WH_0x3e9  41.681471         NaN       Type_A  2021
# 1  0x31fd  2021-05-01     WH_0x3e9  41.681471         NaN       Type_B  2021
# 2  0x3ed2  2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_A  2021
# 3  0x3ed3  2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_B  2021
# 4  0x4a3a  2021-05-01     WH_0x3eb  35.678970 -109.067413       Type_A  2021
#
#   month is_weekend is_warehouse_closed
# 0   May        NaN                  No
# 1   May        Yes                  No
# 2   May        Yes                  No
# 3   May        Yes                  No
# 4   May        Yes                 Yes

# %%
test_data.isnull().sum()
# Out:
# ID                       0
# date                     0
# warehouse_ID             0
# Latitude                98
# Longitude              122
# Product_Type             0
# year                     0
# month                    0
# is_weekend             147
# is_warehouse_closed     49
# dtype: int64

# %%
test_data['warehouse_ID'].unique()
# Out:
# array(['WH_0x3e9', 'WH_0x3ea', 'WH_0x3eb', 'WH_0x3ec', 'WH_0x3ed',
#        'WH_0x3ee', 'WH_0x3ef', 'WH_0x3f0', 'WH_0x3f1', 'WH_0x3f2'],
#       dtype=object)

# %%
from sklearn.experimental import enable_iterative_imputer
# import Iterative imputer
from sklearn.impute import IterativeImputer
iter_impute=IterativeImputer()
iter_imp=pd.DataFrame(iter_impute.fit_transform(test_data[['Latitude','Longitude']]),columns=['Latitude','Longitude'])
iter_imp
# Out:
#        Latitude   Longitude
# 0     41.681471 -101.693099
# 1     41.681471 -101.693099
# 2     38.749077 -105.183060
# 3     38.749077 -105.183060
# 4     35.678970 -109.067413
# ...         ...         ...
# 4895  37.915825  -89.829262
# 4896  48.692551 -116.319862
# 4897  48.692551 -116.319862
# 4898  61.600803 -149.125259
# 4899  61.600803 -149.125259
#
# [4900 rows x 2 columns]

# %%
iter_imp.isnull().sum()
# Out:
# Latitude     0
# Longitude    0
# dtype: int64

# %%
test_data[['Latitude','Longitude']] = iter_imp

# %%
test_data.isnull().sum()
# Out:
# ID                       0
# date                     0
# warehouse_ID             0
# Latitude                 0
# Longitude                0
# Product_Type             0
# year                     0
# month                    0
# is_weekend             147
# is_warehouse_closed     49
# dtype: int64

# %%
test_data['date'] = pd.to_datetime(test_data['date'], errors='coerce')
test_data['weak-of-year'] = test_data['date'].dt.weekofyear
test_data['Quarter'] = test_data.date.dt.quarter
test_data['day-of-week'] = test_data['date'].dt.dayofweek
test_data['days_in_month'] = test_data.date.dt.days_in_month

# %%
test_data.head()
# Out:
#        ID       date warehouse_ID   Latitude   Longitude Product_Type  year  \
# 0  0x31fc 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_A  2021
# 1  0x31fd 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_B  2021
# 2  0x3ed2 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_A  2021
# 3  0x3ed3 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_B  2021
# 4  0x4a3a 2021-05-01     WH_0x3eb  35.678970 -109.067413       Type_A  2021
#
#   month is_weekend is_warehouse_closed  weak-of-year  Quarter  day-of-week  \
# 0   May        NaN                  No            17        2            5
# 1   May        Yes                  No            17        2            5
# 2   May        Yes                  No            17        2            5
# 3   May        Yes                  No            17        2            5
# 4   May        Yes                 Yes            17        2            5
#
#    days_in_month
# 0             31
# 1             31
# 2             31
# 3             31
# 4             31

# %%
test_data['is_warehouse_closed'] = test_data['is_warehouse_closed'].replace('Yes',1)

# %%
test_data['is_weekend'] = test_data['is_weekend'].replace('Yes',1)

# %%
test_data['is_warehouse_closed'] = test_data['is_warehouse_closed'].replace('No',0)

# %%
test_data['is_weekend'] = test_data['is_weekend'].replace('No',0)

# %%
test_data
# Out:
#           ID       date warehouse_ID   Latitude   Longitude Product_Type  \
# 0     0x31fc 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_A
# 1     0x31fd 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_B
# 2     0x3ed2 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_A
# 3     0x3ed3 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_B
# 4     0x4a3a 2021-05-01     WH_0x3eb  35.678970 -109.067413       Type_A
# ...      ...        ...          ...        ...         ...          ...
# 4895  0x713d 2021-12-31     WH_0x3f0  37.915825  -89.829262       Type_B
# 4896  0x76b2 2021-12-31     WH_0x3f1  48.692551 -116.319862       Type_A
# 4897  0x76b3 2021-12-31     WH_0x3f1  48.692551 -116.319862       Type_B
# 4898  0x7b36 2021-12-31     WH_0x3f2  61.600803 -149.125259       Type_A
# 4899  0x7b37 2021-12-31     WH_0x3f2  61.600803 -149.125259       Type_B
#
#       year     month  is_weekend  is_warehouse_closed  weak-of-year  Quarter  \
# 0     2021       May         NaN                  0.0            17        2
# 1     2021       May         1.0                  0.0            17        2
# 2     2021       May         1.0                  0.0            17        2
# 3     2021       May         1.0                  0.0            17        2
# 4     2021       May         1.0                  1.0            17        2
# ...    ...       ...         ...                  ...           ...      ...
# 4895  2021  December         0.0                  1.0            52        4
# 4896  2021  December         0.0                  0.0            52        4
# 4897  2021  December         0.0                  1.0            52        4
# 4898  2021  December         0.0                  0.0            52        4
# 4899  2021  December         0.0                  1.0            52        4
#
#       day-of-week  days_in_month
# 0               5             31
# 1               5             31
# 2               5             31
# 3               5             31
# 4               5             31
# ...           ...            ...
# 4895            4             31
# 4896            4             31
# 4897            4             31
# 4898            4             31
# 4899            4             31
#
# [4900 rows x 14 columns]

# %%
from sklearn.impute import KNNImputer
knnimp= KNNImputer(n_neighbors=3)
knn_imp=pd.DataFrame(knnimp.fit_transform(test_data[['day-of-week','is_warehouse_closed']]),columns=['day-of-week','is_warehouse_closed'])

knn_imp
# Out:
#       day-of-week  is_warehouse_closed
# 0             5.0                  0.0
# 1             5.0                  0.0
# 2             5.0                  0.0
# 3             5.0                  0.0
# 4             5.0                  1.0
# ...           ...                  ...
# 4895          4.0                  1.0
# 4896          4.0                  0.0
# 4897          4.0                  1.0
# 4898          4.0                  0.0
# 4899          4.0                  1.0
#
# [4900 rows x 2 columns]

# %%
test_data[['day-of-week','is_warehouse_closed']] = knn_imp

# %%
iter_impute=IterativeImputer()
iter_imp=pd.DataFrame(iter_impute.fit_transform(test_data[['is_warehouse_closed','is_weekend']]),columns=['is_warehouse_closed','is_weekend'])
iter_imp
# Out:
#       is_warehouse_closed  is_weekend
# 0                     0.0     0.26995
# 1                     0.0     1.00000
# 2                     0.0     1.00000
# 3                     0.0     1.00000
# 4                     1.0     1.00000
# ...                   ...         ...
# 4895                  1.0     0.00000
# 4896                  0.0     0.00000
# 4897                  1.0     0.00000
# 4898                  0.0     0.00000
# 4899                  1.0     0.00000
#
# [4900 rows x 2 columns]

# %%
test_data[['is_warehouse_closed','is_weekend']] = iter_imp

# %%
test_data
# Out:
#           ID       date warehouse_ID   Latitude   Longitude Product_Type  \
# 0     0x31fc 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_A
# 1     0x31fd 2021-05-01     WH_0x3e9  41.681471 -101.693099       Type_B
# 2     0x3ed2 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_A
# 3     0x3ed3 2021-05-01     WH_0x3ea  38.749077 -105.183060       Type_B
# 4     0x4a3a 2021-05-01     WH_0x3eb  35.678970 -109.067413       Type_A
# ...      ...        ...          ...        ...         ...          ...
# 4895  0x713d 2021-12-31     WH_0x3f0  37.915825  -89.829262       Type_B
# 4896  0x76b2 2021-12-31     WH_0x3f1  48.692551 -116.319862       Type_A
# 4897  0x76b3 2021-12-31     WH_0x3f1  48.692551 -116.319862       Type_B
# 4898  0x7b36 2021-12-31     WH_0x3f2  61.600803 -149.125259       Type_A
# 4899  0x7b37 2021-12-31     WH_0x3f2  61.600803 -149.125259       Type_B
#
#       year     month  is_weekend  is_warehouse_closed  weak-of-year  Quarter  \
# 0     2021       May     0.26995                  0.0            17        2
# 1     2021       May     1.00000                  0.0            17        2
# 2     2021       May     1.00000                  0.0            17        2
# 3     2021       May     1.00000                  0.0            17        2
# 4     2021       May     1.00000                  1.0            17        2
# ...    ...       ...         ...                  ...           ...      ...
# 4895  2021  December     0.00000                  1.0            52        4
# 4896  2021  December     0.00000                  0.0            52        4
# 4897  2021  December     0.00000                  1.0            52        4
# 4898  2021  December     0.00000                  0.0            52        4
# 4899  2021  December     0.00000                  1.0            52        4
#
#       day-of-week  days_in_month
# 0             5.0             31
# 1             5.0             31
# 2             5.0             31
# 3             5.0             31
# 4             5.0             31
# ...           ...            ...
# 4895          4.0             31
# 4896          4.0             31
# 4897          4.0             31
# 4898          4.0             31
# 4899          4.0             31
#
# [4900 rows x 14 columns]

# %%
import reverse_geocoder as rg
import pprint
data00=[]
def reverseGeocode(coordinates):
    result=rg.search(coordinates)
    return(result)
if __name__=="__main__":
    coordinates=list(zip(test_data['Latitude'],test_data['Longitude']))
    data12=reverseGeocode(coordinates)
    data00.append(data12)

new_data=pd.DataFrame(data00).transpose()
test_data['state']=new_data[0].apply(lambda x:x.get('admin1'))
test_data['Country']=new_data[0].apply(lambda x:x.get('cc'))

# %%
test_data
# Out:
#       Product_Type  year  month  is_weekend  is_warehouse_closed  \
# 0                0  2021      4     0.26995                  0.0
# 1                1  2021      4     1.00000                  0.0
# 2                0  2021      4     1.00000                  0.0
# 3                1  2021      4     1.00000                  0.0
# 4                0  2021      4     1.00000                  1.0
# ...            ...   ...    ...         ...                  ...
# 4895             1  2021      1     0.00000                  1.0
# 4896             0  2021      1     0.00000                  0.0
# 4897             1  2021      1     0.00000                  1.0
# 4898             0  2021      1     0.00000                  0.0
# 4899             1  2021      1     0.00000                  1.0
#
#       weak-of-year  Quarter  day-of-week  days_in_month     state Country
# 0               17        2          5.0             31  Nebraska      US
# 1               17        2          5.0             31  Nebraska      US
# 2               17        2          5.0             31  Colorado      US
# 3               17        2          5.0             31  Colorado      US
# 4               17        2          5.0             31   Arizona      US
# ...            ...      ...          ...            ...       ...     ...
# 4895            52        4          4.0             31  Illinois      US
# 4896            52        4          4.0             31     Idaho      US
# 4897            52        4          4.0             31     Idaho      US
# 4898            52        4          4.0             31    Alaska      US
# 4899            52        4          4.0             31    Alaska      US
#
# [4900 rows x 11 columns]

# %%
test_data.drop(columns=['ID','warehouse_ID','Latitude','Longitude','date'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
test_data['Product_Type'] = lab_enc.fit_transform(test_data['Product_Type'])
test_data['month'] = lab_enc.fit_transform(test_data['month'])
test_data['state'] = lab_enc.fit_transform(test_data['state'])
test_data['Country'] = lab_enc.fit_transform(test_data['Country'])

# %%
test_data.shape
# Out:
# (4900, 11)

# %%
X.shape
# Out:
# (15272, 11)

# %%
pred = rf.predict(test_data)

# %%
pred
# Out:
# array([29.6806591 ,  8.80110476, 28.70620582, ...,  4.96330951,
#        30.85730641,  6.05909076])
